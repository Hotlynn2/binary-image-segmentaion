# %% [markdown]
# # J235 NEW

# %%
import pandas as pd
import numpy as np

# %%
file = pd. ExcelFile('sub.xlsx')
j235new = pd. read_excel(file, 'j235new')
jordan235new = pd. read_excel(file, 'jordan235')

# %%
j235new
# Out:
#      ObjectID * Shape *       x        y         xnew         ynew      F5  \
# 0             1   Point  436123  5826713  6242.334577 -6040.339266  <Null>
# 1             2   Point  435924  5828006  6159.391321 -5501.365682  <Null>
# 2             3   Point  436458  5827661  6381.962670 -5645.175339  <Null>
# 3             4   Point  436166  5828564  6260.256988 -5268.769194  <Null>
# 4             5   Point  436283  5826144  6309.022621 -6277.520990  <Null>
# ..          ...     ...     ...      ...          ...          ...     ...
# 159         162   Point  435330  5827790  5911.811955 -5591.403033  <Null>
# 160         163   Point  433577  5827915  5181.161067 -5539.298085  <Null>
# 161         378   Point  437441  5827198  6791.677344 -5838.172067  <Null>
# 162         381   Point  435778  5828861  6098.538480 -5144.967837  <Null>
# 163         921   Point  436243  5825970  6292.350610 -6350.051077  <Null>
#
# ...

# %%
x235newcord_list = j235new['x'].to_list()
# len(xcord_list)
x235newcord_list
y235newcord_list = j235new['y'].to_list()
# len(xcord_list)
y235newcord_list
# Out:
# [5826713,
#  5828006,
#  5827661,
#  5828564,
#  5826144,
#  5828316,
#  5828237,
#  5827166,
#  5828586,
#  5826387,
#  5827689,
#  5828116,
#  5827992,
#  5829145,
#  5827320,
#  5828998,
#  5828926,
#  5829277,
#  5827663,
#  5827902,
#  5827825,
#  5831157,
#  5827419,
#  5827966,
#  5828903,
#  5828271,
#  5828289,
#  5827682,
#  5827967,
#  5827028,
#  5827713,
#  5828018,
#  5827903,
#  5828090,
#  5826593,
#  5828587,
#  5828109,
#  5831108,
#  5827250,
#  5827585,
#  5827736,
#  5828387,
#  5827477,
#  5827445,
#  5826777,
#  5827723,
#  5828245,
#  5828289,
#  5830044,
#  5828828,
#  5826451,
#  5831494,
#  5827901,
#  5827462,
#  5826871,
#  5828931,
#  5828308,
#  5830782,
#  5830715,
#  5827250,
#  5828795,
#  5827798,
#  5827436,
#  5827697,
#  5827476,
#  5828460,
#  5828195,
#  5827506,
#  5827405,
#  5831509,
#  5829758,
#  5828622,
#  5830874,
#  5827635,
#  5826751,
#  5826544,
#  5827679,
#  5826479,
#  5828610,
#  5828727,
#  5831180,
#  5831476,
#  5828679,
# ...

# %%
jordan235new
# Out:
#       id                                label       x        y  targets  \
# 0      0  JORDAN_235_P1_201901281204_MGA94_55  436123  5826713      1.0
# 1      1  JORDAN_235_P1_201901281204_MGA94_55  435924  5828006      1.0
# 2      2  JORDAN_235_P1_201901281204_MGA94_55  436458  5827661      1.0
# 3      3  JORDAN_235_P1_201901281204_MGA94_55  436166  5828564      1.0
# 4      4  JORDAN_235_P1_201901281204_MGA94_55  436283  5826144      1.0
# ..   ...                                  ...     ...      ...      ...
# 995  995  JORDAN_235_P1_201901281204_MGA94_55  432357  5824848      NaN
# 996  996  JORDAN_235_P1_201901281204_MGA94_55  428698  5827598      NaN
# 997  997  JORDAN_235_P1_201901281204_MGA94_55  431145  5826783      NaN
# 998  998  JORDAN_235_P1_201901281204_MGA94_55  436867  5826310      NaN
# 999  999  JORDAN_235_P1_201901281204_MGA94_55  436771  5832052      NaN
#
#         dateTimeLocal      dateTimeUTC
# 0    28/01/2019 12:04  28/01/2019 1:04
# ...

# %%
jordan235new['target'] = np.where( (jordan235new['x'].isin(x235newcord_list) & (jordan235new['y'].isin(y235newcord_list) )), 1, 0)

# %%
jordan235new = jordan235new.drop('targets', axis =1)

# %%
jordan235new
# Out:
#       id                                label       x        y  \
# 0      0  JORDAN_235_P1_201901281204_MGA94_55  436123  5826713
# 1      1  JORDAN_235_P1_201901281204_MGA94_55  435924  5828006
# 2      2  JORDAN_235_P1_201901281204_MGA94_55  436458  5827661
# 3      3  JORDAN_235_P1_201901281204_MGA94_55  436166  5828564
# 4      4  JORDAN_235_P1_201901281204_MGA94_55  436283  5826144
# ..   ...                                  ...     ...      ...
# 995  995  JORDAN_235_P1_201901281204_MGA94_55  432357  5824848
# 996  996  JORDAN_235_P1_201901281204_MGA94_55  428698  5827598
# 997  997  JORDAN_235_P1_201901281204_MGA94_55  431145  5826783
# 998  998  JORDAN_235_P1_201901281204_MGA94_55  436867  5826310
# 999  999  JORDAN_235_P1_201901281204_MGA94_55  436771  5832052
#
#         dateTimeLocal      dateTimeUTC  target
# 0    28/01/2019 12:04  28/01/2019 1:04       1
# 1    28/01/2019 12:04  28/01/2019 1:04       1
# 2    28/01/2019 12:04  28/01/2019 1:04       1
# ...

# %% [markdown]
# # J 294

# %%
file = pd. ExcelFile('sub.xlsx')
j294 = pd. read_excel(file, 'j294')
jordan294 = pd. read_excel(file, 'jordan294')

# %%
j294
# Out:
#      ObjectID * Shape *  FID_j294  targetid  \
# 0            13   Point         1      1000
# 1            67   Point         2      1001
# 2           154   Point         3      1002
# 3           110   Point         4      1003
# 4           172   Point         5      1004
# ..          ...     ...       ...       ...
# 177          15   Point       727      1726
# 178           3   Point       768      1767
# 179          26   Point       777      1776
# 180         152   Point       898      1897
# 181           9   Point       941      1940
#
#                                    label       x        y       dateTimeLocal  \
# 0    JORDAN_294_P1_201902011150_MGA94_55  441973  5818162 2019-01-02 11:50:00
# 1    JORDAN_294_P1_201902011150_MGA94_55  439741  5824011 2019-01-02 11:50:00
# 2    JORDAN_294_P1_201902011150_MGA94_55  435364  5828594 2019-01-02 11:50:00
# 3    JORDAN_294_P1_201902011150_MGA94_55  438875  5826479 2019-01-02 11:50:00
# ...

# %%
x294cord_list = j294['x'].to_list()
# len(xcord_list)
x294cord_list
y294cord_list = j294['y'].to_list()
# len(xcord_list)
x294cord_list
# Out:
# [441973,
#  439741,
#  435364,
#  438875,
#  431573,
#  434486,
#  438485,
#  438718,
#  435156,
#  437404,
#  437621,
#  437099,
#  435647,
#  436514,
#  441062,
#  441182,
#  438051,
#  432800,
#  442522,
#  437007,
#  442857,
#  435810,
#  430090,
#  435948,
#  443638,
#  430383,
#  435694,
#  440986,
#  440199,
#  433705,
#  438840,
#  442987,
#  440948,
#  441408,
#  439626,
#  439548,
#  441016,
#  438647,
#  431446,
#  437858,
#  436742,
#  437113,
#  442168,
#  432082,
#  440657,
#  436354,
#  439774,
#  441020,
#  436968,
#  443486,
#  438459,
#  432562,
#  434956,
#  432746,
#  442457,
#  440487,
#  441031,
#  437603,
#  432641,
#  441449,
#  437164,
#  431735,
#  434419,
#  439604,
#  438410,
#  431929,
#  440194,
#  438068,
#  434351,
#  438572,
#  441607,
#  434405,
#  439061,
#  433546,
#  433645,
#  436531,
#  434431,
#  435204,
#  434203,
#  439873,
#  435252,
#  439160,
#  437485,
#  441610,
#  441209,
#  442278,
#  443503,
#  437060,
#  437410,
#  440950,
# ...

# %%
jordan294
# Out:
#        id                                label       x        y  \
# 0    1000  JORDAN_294_P1_201902011150_MGA94_55  441973  5818162
# 1    1001  JORDAN_294_P1_201902011150_MGA94_55  439741  5824011
# 2    1002  JORDAN_294_P1_201902011150_MGA94_55  435364  5828594
# 3    1003  JORDAN_294_P1_201902011150_MGA94_55  438875  5826479
# 4    1004  JORDAN_294_P1_201902011150_MGA94_55  431573  5830137
# ..    ...                                  ...     ...      ...
# 995  1995  JORDAN_294_P1_201902011150_MGA94_55  426092  5826783
# 996  1996  JORDAN_294_P1_201902011150_MGA94_55  433882  5824840
# 997  1997  JORDAN_294_P1_201902011150_MGA94_55  429901  5832712
# 998  1998  JORDAN_294_P1_201902011150_MGA94_55  430063  5830582
# 999  1999  JORDAN_294_P1_201902011150_MGA94_55  434723  5821075
#
#           dateTimeLocal         dateTimeUTC
# 0   2019-01-02 11:50:00 2019-01-02 00:50:00
# 1   2019-01-02 11:50:00 2019-01-02 00:50:00
# 2   2019-01-02 11:50:00 2019-01-02 00:50:00
# ...

# %%
jordan294['target'] = np.where( (jordan294['x'].isin(x294cord_list) & (jordan294['y'].isin(y294cord_list) )), 1, 0)

# %%
jordan294
# Out:
#        id                                label       x        y  \
# 0    1000  JORDAN_294_P1_201902011150_MGA94_55  441973  5818162
# 1    1001  JORDAN_294_P1_201902011150_MGA94_55  439741  5824011
# 2    1002  JORDAN_294_P1_201902011150_MGA94_55  435364  5828594
# 3    1003  JORDAN_294_P1_201902011150_MGA94_55  438875  5826479
# 4    1004  JORDAN_294_P1_201902011150_MGA94_55  431573  5830137
# ..    ...                                  ...     ...      ...
# 995  1995  JORDAN_294_P1_201902011150_MGA94_55  426092  5826783
# 996  1996  JORDAN_294_P1_201902011150_MGA94_55  433882  5824840
# 997  1997  JORDAN_294_P1_201902011150_MGA94_55  429901  5832712
# 998  1998  JORDAN_294_P1_201902011150_MGA94_55  430063  5830582
# 999  1999  JORDAN_294_P1_201902011150_MGA94_55  434723  5821075
#
#           dateTimeLocal         dateTimeUTC  target
# 0   2019-01-02 11:50:00 2019-01-02 00:50:00       1
# 1   2019-01-02 11:50:00 2019-01-02 00:50:00       1
# ...

# %% [markdown]
# # W313

# %%
file = pd. ExcelFile('sub.xlsx')
w313 = pd. read_excel(file, 'w313')
walhalla313 = pd. read_excel(file, 'walhalla313')

# %%
w313
# Out:
#      ObjectID * Shape *  FID_w313  targetid  \
# 0           373   Point         1      2000
# 1           333   Point         2      2001
# 2            10   Point         3      2002
# 3           367   Point         4      2003
# 4            74   Point         5      2004
# ..          ...     ...       ...       ...
# 369         176   Point       953      2952
# 370         185   Point       985      2984
# 371         374   Point       987      2986
# 372         275   Point       999      2998
# 373         361   Point      1000      2999
#
#                                      label       x        y  \
# 0    WALHALLA_313_P1_201902020733_MGA94_55  458876  5804531
# 1    WALHALLA_313_P1_201902020733_MGA94_55  457629  5804150
# 2    WALHALLA_313_P1_201902020733_MGA94_55  459602  5801349
# 3    WALHALLA_313_P1_201902020733_MGA94_55  458703  5804479
# 4    WALHALLA_313_P1_201902020733_MGA94_55  459436  5802070
# ..                                     ...     ...      ...
# ...

# %%
x313cord_list = w313['x'].to_list()
# len(xcord_list)
x313cord_list
y313cord_list = w313['y'].to_list()
# len(xcord_list)
y313cord_list
# Out:
# [5804531,
#  5804150,
#  5801349,
#  5804479,
#  5802070,
#  5803195,
#  5804144,
#  5803519,
#  5801984,
#  5803963,
#  5802806,
#  5803275,
#  5802801,
#  5802571,
#  5802602,
#  5804085,
#  5804001,
#  5802754,
#  5802760,
#  5801258,
#  5802216,
#  5802701,
#  5804056,
#  5801942,
#  5802296,
#  5801998,
#  5801955,
#  5803845,
#  5802860,
#  5803659,
#  5803403,
#  5801926,
#  5804527,
#  5804325,
#  5803250,
#  5804311,
#  5804314,
#  5801965,
#  5802635,
#  5802139,
#  5803250,
#  5802779,
#  5803506,
#  5804360,
#  5803889,
#  5802146,
#  5803510,
#  5802557,
#  5801252,
#  5802510,
#  5804276,
#  5801322,
#  5801569,
#  5803619,
#  5803208,
#  5804096,
#  5801977,
#  5803812,
#  5804267,
#  5803934,
#  5803989,
#  5802205,
#  5802503,
#  5803353,
#  5804094,
#  5802423,
#  5801890,
#  5803828,
#  5801688,
#  5804007,
#  5803320,
#  5802247,
#  5803796,
#  5803810,
#  5804400,
#  5803475,
#  5803372,
#  5802619,
#  5801710,
#  5802840,
#  5803376,
#  5801895,
#  5802874,
# ...

# %%
walhalla313
# Out:
#        id                                  label       x        y  \
# 0    2000  WALHALLA_313_P1_201902020733_MGA94_55  458876  5804531
# 1    2001  WALHALLA_313_P1_201902020733_MGA94_55  457629  5804150
# 2    2002  WALHALLA_313_P1_201902020733_MGA94_55  459602  5801349
# 3    2003  WALHALLA_313_P1_201902020733_MGA94_55  458703  5804479
# 4    2004  WALHALLA_313_P1_201902020733_MGA94_55  459436  5802070
# ..    ...                                    ...     ...      ...
# 995  2995  WALHALLA_313_P1_201902020733_MGA94_55  457685  5801625
# 996  2996  WALHALLA_313_P1_201902020733_MGA94_55  456728  5801387
# 997  2997  WALHALLA_313_P1_201902020733_MGA94_55  460610  5801977
# 998  2998  WALHALLA_313_P1_201902020733_MGA94_55  459344  5803800
# 999  2999  WALHALLA_313_P1_201902020733_MGA94_55  459090  5804399
#
#           dateTimeLocal         dateTimeUTC
# 0   2019-02-02 07:33:00 2019-01-02 20:33:00
# 1   2019-02-02 07:33:00 2019-01-02 20:33:00
# ...

# %%
walhalla313['target'] = np.where( (walhalla313['x'].isin(x313cord_list) & (walhalla313['y'].isin(y313cord_list) )), 1, 0)

# %%
walhalla313
# Out:
#        id                                  label       x        y  \
# 0    2000  WALHALLA_313_P1_201902020733_MGA94_55  458876  5804531
# 1    2001  WALHALLA_313_P1_201902020733_MGA94_55  457629  5804150
# 2    2002  WALHALLA_313_P1_201902020733_MGA94_55  459602  5801349
# 3    2003  WALHALLA_313_P1_201902020733_MGA94_55  458703  5804479
# 4    2004  WALHALLA_313_P1_201902020733_MGA94_55  459436  5802070
# ..    ...                                    ...     ...      ...
# 995  2995  WALHALLA_313_P1_201902020733_MGA94_55  457685  5801625
# 996  2996  WALHALLA_313_P1_201902020733_MGA94_55  456728  5801387
# 997  2997  WALHALLA_313_P1_201902020733_MGA94_55  460610  5801977
# 998  2998  WALHALLA_313_P1_201902020733_MGA94_55  459344  5803800
# 999  2999  WALHALLA_313_P1_201902020733_MGA94_55  459090  5804399
#
#           dateTimeLocal         dateTimeUTC  target
# 0   2019-02-02 07:33:00 2019-01-02 20:33:00       1
# 1   2019-02-02 07:33:00 2019-01-02 20:33:00       1
# ...

# %% [markdown]
# # W353 NEW6

# %%
file = pd. ExcelFile('sub.xlsx')
w353new6 = pd. read_excel(file, 'w353new6')

# %%
w353new6
# Out:
#      ObjectID * Shape *       x        y         xnew         ynew      F5  \
# 0             1   Point  457193  5800092  3772.662631 -6314.453191  <Null>
# 1             2   Point  458264  5802853  4219.286988 -5163.057447  <Null>
# 2             3   Point  459595  5802087  4774.335558 -5482.495745  <Null>
# 3             4   Point  457524  5800069  3910.694995 -6324.044681  <Null>
# 4             5   Point  459132  5798938  4581.257054 -6795.695745  <Null>
# ..          ...     ...     ...      ...          ...          ...     ...
# 487         922   Point  460804  5802569  5278.508151 -5281.491489  <Null>
# 488         930   Point  460644  5801636  5211.785558 -5670.572340  <Null>
# 489         954   Point  461512  5798913  5573.755624 -6806.121277  <Null>
# 490         955   Point  460535  5799155  5166.330791 -6705.202128  <Null>
# 491         995   Point  459955  5797391  4924.461392 -7440.827660  <Null>
#
# ...

# %%
x353new6cord_list = w353new6['x'].to_list()
# len(xcord_list)
x353new6cord_list
y353new6cord_list = w353new6['y'].to_list()
# len(xcord_list)
y353new6cord_list
# Out:
# [5800092,
#  5802853,
#  5802087,
#  5800069,
#  5798938,
#  5803424,
#  5802477,
#  5799370,
#  5800879,
#  5798871,
#  5798662,
#  5799628,
#  5803596,
#  5802020,
#  5800861,
#  5798751,
#  5798881,
#  5802661,
#  5800322,
#  5802392,
#  5802792,
#  5803322,
#  5799112,
#  5799479,
#  5798894,
#  5798291,
#  5798361,
#  5800135,
#  5801049,
#  5799779,
#  5798590,
#  5801299,
#  5799445,
#  5800131,
#  5800665,
#  5804019,
#  5802914,
#  5798569,
#  5800539,
#  5800242,
#  5797050,
#  5799239,
#  5801329,
#  5802665,
#  5804328,
#  5799118,
#  5799908,
#  5802274,
#  5799963,
#  5800636,
#  5801455,
#  5802695,
#  5801250,
#  5802752,
#  5802863,
#  5800638,
#  5798678,
#  5803755,
#  5804604,
#  5802725,
#  5803412,
#  5799810,
#  5797859,
#  5800454,
#  5801632,
#  5802379,
#  5802883,
#  5802936,
#  5802719,
#  5802899,
#  5804479,
#  5803824,
#  5802705,
#  5803469,
#  5797265,
#  5800191,
#  5804463,
#  5805229,
#  5799783,
#  5803727,
#  5799343,
#  5802374,
#  5802138,
# ...

# %%
walhalla353new6 = pd. read_excel(file, 'walhalla353')

# %%
walhalla353new6['target'] = np.where( (walhalla353new6['x'].isin(x353new6cord_list) & (walhalla353new6['y'].isin(y353new6cord_list) )), 1, 0)

# %%
walhalla353new6
# Out:
#        id                                  label       x        y  \
# 0    3000  WALHALLA_353_P1_201902031625_MGA94_55  457193  5800092
# 1    3001  WALHALLA_353_P1_201902031625_MGA94_55  458264  5802853
# 2    3002  WALHALLA_353_P1_201902031625_MGA94_55  459595  5802087
# 3    3003  WALHALLA_353_P1_201902031625_MGA94_55  457524  5800069
# 4    3004  WALHALLA_353_P1_201902031625_MGA94_55  459132  5798938
# ..    ...                                    ...     ...      ...
# 995  3995  WALHALLA_353_P1_201902031625_MGA94_55  463611  5804106
# 996  3996  WALHALLA_353_P1_201902031625_MGA94_55  460754  5803882
# 997  3997  WALHALLA_353_P1_201902031625_MGA94_55  462812  5800143
# 998  3998  WALHALLA_353_P1_201902031625_MGA94_55  461904  5804808
# 999  3999  WALHALLA_353_P1_201902031625_MGA94_55  461867  5799215
#
#           dateTimeLocal         dateTimeUTC  target
# 0   2019-03-02 16:25:00 2019-03-02 05:25:00       1
# 1   2019-03-02 16:25:00 2019-03-02 05:25:00       1
# ...

# %% [markdown]
# # M91 NEW1

# %%
file = pd. ExcelFile('sub.xlsx')
m91new1 = pd. read_excel(file, 'm91new1')
macalister91new1 = pd. read_excel(file, 'macalister91')

# %%
m91new1
# Out:
#      ObjectID * Shape *    id                                      label  \
# 0             1   Point  4000  MACALISTER91_648_P1_201903070444_MGA94_55
# 1             2   Point  4003  MACALISTER91_648_P1_201903070444_MGA94_55
# 2             3   Point  4004  MACALISTER91_648_P1_201903070444_MGA94_55
# 3             4   Point  4008  MACALISTER91_648_P1_201903070444_MGA94_55
# 4             5   Point  4009  MACALISTER91_648_P1_201903070444_MGA94_55
# ..          ...     ...   ...                                        ...
# 409         410   Point  4987  MACALISTER91_648_P1_201903070444_MGA94_55
# 410         411   Point  4989  MACALISTER91_648_P1_201903070444_MGA94_55
# 411         412   Point  4992  MACALISTER91_648_P1_201903070444_MGA94_55
# 412         413   Point  4994  MACALISTER91_648_P1_201903070444_MGA94_55
# 413         414   Point  4995  MACALISTER91_648_P1_201903070444_MGA94_55
#
#           x        y       dateTimeLocal         dateTimeUTC  target
# ...

# %%
x91new1cord_list = m91new1['x'].to_list()
# len(xcord_list)
x91new1cord_list
y91new1cord_list = m91new1['y'].to_list()
# len(xcord_list)
y91new1cord_list
# Out:
# [5838892,
#  5836266,
#  5824503,
#  5821041,
#  5837216,
#  5824901,
#  5835080,
#  5831142,
#  5825003,
#  5837980,
#  5838568,
#  5828063,
#  5832515,
#  5838024,
#  5833527,
#  5825066,
#  5838202,
#  5821733,
#  5832686,
#  5838184,
#  5836594,
#  5826197,
#  5839922,
#  5830154,
#  5840326,
#  5828723,
#  5823981,
#  5834540,
#  5837776,
#  5840485,
#  5828745,
#  5834439,
#  5839041,
#  5837099,
#  5829492,
#  5833010,
#  5837272,
#  5841696,
#  5833935,
#  5834193,
#  5830698,
#  5840088,
#  5828132,
#  5837429,
#  5832589,
#  5840411,
#  5824180,
#  5834063,
#  5833356,
#  5827123,
#  5836086,
#  5825066,
#  5836756,
#  5827756,
#  5834111,
#  5836612,
#  5831559,
#  5833056,
#  5830436,
#  5838271,
#  5837229,
#  5831485,
#  5834983,
#  5825266,
#  5834906,
#  5829525,
#  5834759,
#  5838877,
#  5827100,
#  5838559,
#  5828948,
#  5839343,
#  5834245,
#  5822258,
#  5819979,
#  5830843,
#  5838041,
#  5834991,
#  5837128,
#  5834646,
#  5832322,
#  5827765,
#  5833292,
# ...

# %%
macalister91new1
# Out:
#        id                                      label       x        y  \
# 0    4000  MACALISTER91_648_P1_201903070444_MGA94_55  475218  5838892
# 1    4001  MACALISTER91_648_P1_201903070444_MGA94_55  469152  5824026
# 2    4002  MACALISTER91_648_P1_201903070444_MGA94_55  478531  5841705
# 3    4003  MACALISTER91_648_P1_201903070444_MGA94_55  473144  5836266
# 4    4004  MACALISTER91_648_P1_201903070444_MGA94_55  473627  5824503
# ..    ...                                        ...     ...      ...
# 995  4995  MACALISTER91_648_P1_201903070444_MGA94_55  478789  5826475
# 996  4996  MACALISTER91_648_P1_201903070444_MGA94_55  470400  5845253
# 997  4997  MACALISTER91_648_P1_201903070444_MGA94_55  480548  5842533
# 998  4998  MACALISTER91_648_P1_201903070444_MGA94_55  473586  5815882
# 999  4999  MACALISTER91_648_P1_201903070444_MGA94_55  475119  5841922
#
#           dateTimeLocal         dateTimeUTC
# 0   2019-07-03 04:44:00 2019-06-03 17:44:00
# ...

# %%
macalister91new1['target'] = np.where( (macalister91new1['x'].isin(x91new1cord_list) & (macalister91new1['y'].isin(y91new1cord_list) )), 1, 0)

# %%
macalister91new1
# Out:
#        id                                      label       x        y  \
# 0    4000  MACALISTER91_648_P1_201903070444_MGA94_55  475218  5838892
# 1    4001  MACALISTER91_648_P1_201903070444_MGA94_55  469152  5824026
# 2    4002  MACALISTER91_648_P1_201903070444_MGA94_55  478531  5841705
# 3    4003  MACALISTER91_648_P1_201903070444_MGA94_55  473144  5836266
# 4    4004  MACALISTER91_648_P1_201903070444_MGA94_55  473627  5824503
# ..    ...                                        ...     ...      ...
# 995  4995  MACALISTER91_648_P1_201903070444_MGA94_55  478789  5826475
# 996  4996  MACALISTER91_648_P1_201903070444_MGA94_55  470400  5845253
# 997  4997  MACALISTER91_648_P1_201903070444_MGA94_55  480548  5842533
# 998  4998  MACALISTER91_648_P1_201903070444_MGA94_55  473586  5815882
# 999  4999  MACALISTER91_648_P1_201903070444_MGA94_55  475119  5841922
#
#           dateTimeLocal         dateTimeUTC  target
# 0   2019-07-03 04:44:00 2019-06-03 17:44:00       1
# ...

# %%
len(macalister91new1.loc[macalister91new1['target']==1])
# Out:
# 414

# %% [markdown]
# ## POLYSUB NEW 8

# %%
polysubnew8 = pd.concat([jordan235new, jordan294, walhalla313, walhalla353new6, macalister91new1], axis=0)

# %%
len(polysubnew8.loc[polysubnew8['target']==1])
# Out:
# 1626

# %%
polysubnew8.to_csv('polysubnew_13th.csv')
